# %%
import jieba

# %%
jieba.load_userdict("./my_dict.txt")

txt = "百战程序员提供海量高品质课程"

# 全模式
seg_list = jieba.cut(txt, cut_all=True)
print("/".join(seg_list))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/s1/h4hmcl_d6s9d2nvrdjcxq3kh0000gn/T/jieba.cache
# Loading model cost 0.194 seconds.
# Prefix dict has been built successfully.
# 百战/百战程序员/程序/程序员/提供/海量/高品质/品质/课程
