# %%
import cv2

# %%
# 打开视频文件
cap = cv2.VideoCapture('animal.mp4')

# 检查摄像头是否打开
if not cap.isOpened():
    print("打开视频失败")
    exit()

while True:
    # 读取每一帧
    ret,frame = cap.read()

    # 判断图像是否读取成功
    if not ret:
        print("图像读取失败")
        break

    # 显示图像
    cv2.imshow("frame",frame)

    if cv2.waitKey(1) == ord('q'):
        break

# 释放摄像头
cap.release()
cv2.destroyAllWindows()
# Out:
# 图像读取失败

# %%
# 打开视频文件
cap = cv2.VideoCapture('animal.mp4')

# 检查摄像头是否打开
if not cap.isOpened():
    print("打开视频失败")
    exit()

while True:
    # 读取每一帧
    ret,frame = cap.read()

    # 判断图像是否读取成功
    if not ret:
        print("图像读取失败")
        break

    # 显示图像
    cv2.imshow("frame",frame)

    if cv2.waitKey(1) == ord('q'):
        break

# 释放摄像头
cap.release()
cv2.destroyAllWindows()
# Out:
# 图像读取失败
