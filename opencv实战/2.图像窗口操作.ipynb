# %%
import cv2

# %%
cv2.namedWindow("preview", cv2.WINDOW_AUTOSIZE)

# 显示一个图像窗口，传入0，以为显示默认摄像头画面
cv2.imshow("parrot", 0)

key = cv2.waitKey(0)

if (key == ord('q')):
    exit()

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 # 显示一个图像窗口，传入0，以为显示默认摄像头画面
#       4 cv2.imshow("parrot", 0)
# ----> 6 key = cv2.waitKey(0)
#       8 if (key == ord('q')):
#       9     exit()
#
# KeyboardInterrupt:
